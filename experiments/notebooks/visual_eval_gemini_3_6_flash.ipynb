# %% [markdown]
# # Visual Evaluation - Gemini 3.6 Flash
#
# Runs Gemini 3.6 Flash VLM on all 40 eval scenes. Writes xlsx to data/analysis_gemini_3_6_flash/.

# %%
import sys, os, sqlite3, json, subprocess
from pathlib import Path
import numpy as np
import pandas as pd

ROOT = Path.cwd()
for p in [ROOT] + list(ROOT.parents):
    if (p / '.gitignore').exists():
        ROOT = p; break
sys.path.insert(0, str(ROOT / 'backend/src'))
os.environ['PROJECT_ROOT'] = str(ROOT)

# Load .env for API keys
env_path = ROOT / 'backend' / '.env'
if env_path.exists():
    for line in env_path.read_text().splitlines():
        line = line.strip()
        if line and not line.startswith('#') and '=' in line:
            k, v = line.split('=', 1)
            os.environ.setdefault(k.strip(), v.strip())

ABLATION_DIR = ROOT / 'data' / 'ablation_gemini_3_6_flash'
VIDEO_DIR = ROOT / 'data/videos/eval'
GT_PATH = ROOT / 'data/videos/eval/ground_truth.xlsx'

from service.impl.visual_service_impl import VisualServiceImpl
from service.impl.interval_service_impl import IntervalServiceImpl
from service.impl.events_service_impl import queries_for_condition
from utils.database import setup_database
from utils.vlm_client import VLMClient

print(f'Project root: {{ROOT}}')
print(f'Dataset: data/videos/eval')
# Out:
# Project root: {ROOT}
# Dataset: data/videos/eval

# %%
# ── Constants ──
GRID_ROWS, GRID_COLS = 2, 4
SAMPLING_RATE = 24
VLM_DELAY = 0.1
MAX_RETRIES = 10
PROVIDER = 'gemini'
MODEL = "gemini-3.6-flash"
LABEL = 'gemini_3_6_flash'

DELTAS = {
    "delta_visual_vehicle_escape": 50,
    "delta_visual_loitering": 120,
    "delta_visual_handoff": 240,
}

ANALYSIS_DIR = ROOT / 'data' / 'analysis_gemini_3_6_flash'
ANALYSIS_DIR.mkdir(parents=True, exist_ok=True)
ABLATION_DIR.mkdir(parents=True, exist_ok=True)

# %%
# ── Load GT ──
gt = pd.read_excel(GT_PATH, sheet_name='Ground Truth')
gt_visual = gt[gt['modality'] == 'visual'].dropna(subset=['scene'])
gt_visual['scene'] = gt_visual['scene'].astype(int)

expected_df = pd.read_excel(GT_PATH, sheet_name='Expected Events')

print(f'Visual GT rows: {len(gt_visual)}')
print(f'Expected events: {len(expected_df)}')
# Out:
# Visual GT rows: 62
# Expected events: 40

# %%
# ── Run VLM pipeline + build intervals ──
db_path = ABLATION_DIR / f'gemini_3_6_flash.db'
if db_path.exists():
    db_path.unlink()
conn, cur = setup_database(db_path)
client = VLMClient(provider=PROVIDER, model=MODEL, temperature=0.0, seed=42)
visual = VisualServiceImpl(max_retries=MAX_RETRIES)

for scene in sorted(expected_df['scene'].unique()):
    aid = f'{LABEL}_s{scene}'
    existing = conn.execute(
        'SELECT COUNT(*) FROM VisualPerInterval WHERE AnalysisID = ?', (aid,)
    ).fetchone()[0]
    if existing > 0:
        print(f'  Scene {scene}: skipped ({existing} VPI)')
        continue
    video = VIDEO_DIR / f'scene{scene}.mp4'
    if not video.exists():
        print(f'  Scene {scene}: video not found, skipping')
        continue
    print(f'  Scene {scene}: running VLM...')
    visual.run_pipeline(
        video_path=str(video), conn=conn, client=client,
        grid_rows=GRID_ROWS, grid_cols=GRID_COLS,
        sampling_rate=SAMPLING_RATE, min_interval=VLM_DELAY,
        analysis_id=aid,
        log=print,
    )

conn.close()
print('VLM + interval building done.')
# Out:
#   Scene 1: running VLM...
# Starting video analysis: /home/ghiffaryr/iseql/multimodal-surveillance-iseql/data/videos/eval/scene1.mp4
# Provider: gemini, Model: gemini-3.6-flash, Grid: 2x4
# Sampling rate: 1 frame every 24 video frames
# --- FRAME 0 ---
# --- Frame 0 (gemini) ---
# Calling gemini API (attempt 1/10)
#   -> New object 1 (person)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 24 ---
# --- Frame 24 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 48 ---
# --- Frame 48 (gemini) ---
# Rate limiter: waiting 0.05 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 72 ---
# --- Frame 72 (gemini) ---
# Rate limiter: waiting 0.04 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: fearful_expression(1)
#   -> Saved relation: Frame=72, EventID=1, Type=fearful_expression, Actor=1
# --- FRAME 96 ---
# --- Frame 96 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: fearful_expression(1)
#   -> Saved relation: Frame=96, EventID=1, Type=fearful_expression, Actor=1
# --- FRAME 120 ---
# --- Frame 120 (gemini) ---
# Rate limiter: waiting 0.06 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: fearful_expression(1)
#   -> Saved relation: Frame=120, EventID=1, Type=fearful_expression, Actor=1
# --- FRAME 144 ---
# --- Frame 144 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: gesturing(1) fearful_expression(1) distressed_face(1)
#   -> Saved relation: Frame=144, EventID=1, Type=gesturing, Actor=1
#   -> Saved relation: Frame=144, EventID=2, Type=fearful_expression, Actor=1
#   -> Saved relation: Frame=144, EventID=3, Type=distressed_face, Actor=1
# --- FRAME 168 ---
# --- Frame 168 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(1) fearful_expression(1)
#   -> Saved relation: Frame=168, EventID=1, Type=running, Actor=1
#   -> Saved relation: Frame=168, EventID=2, Type=fearful_expression, Actor=1
# --- FRAME 192 ---
# --- Frame 192 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(1)
#   -> Saved relation: Frame=192, EventID=1, Type=running, Actor=1
# --- FRAME 216 ---
# --- Frame 216 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 240 ---
# --- Frame 240 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# VLM analysis complete. 241 video frames processed.
# Starting post-processing (sampling rate: 24)...
# Loaded 9 vis-relation rows.
# Computing duration intervals with merge logic...
# Consolidated 4 unique relation intervals.
# Filtered to 4 intervals with valid duration; saving...
# Intervals saved successfully.
# Interval construction complete.
#   Scene 2: running VLM...
# Starting video analysis: /home/ghiffaryr/iseql/multimodal-surveillance-iseql/data/videos/eval/scene2.mp4
# Provider: gemini, Model: gemini-3.6-flash, Grid: 2x4
# Sampling rate: 1 frame every 24 video frames
# --- FRAME 0 ---
# --- Frame 0 (gemini) ---
# Rate limiter: waiting 0.05 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> New object 1 (person)
#   -> New object 2 (car)
#   -> New object 3 (car)
#   -> New object 4 (car)
#   -> New object 5 (car)
#   -> New object 6 (car)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 24 ---
# --- Frame 24 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 48 ---
# --- Frame 48 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 72 ---
# --- Frame 72 (gemini) ---
# Rate limiter: waiting 0.04 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: fearful_expression(1)
#   -> Saved relation: Frame=72, EventID=1, Type=fearful_expression, Actor=1
# --- FRAME 96 ---
# --- Frame 96 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: gesturing(1) fearful_expression(1)
#   -> Saved relation: Frame=96, EventID=1, Type=gesturing, Actor=1
#   -> Saved relation: Frame=96, EventID=2, Type=fearful_expression, Actor=1
# --- FRAME 120 ---
# --- Frame 120 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: fearful_expression(1)
#   -> Saved relation: Frame=120, EventID=1, Type=fearful_expression, Actor=1
# --- FRAME 144 ---
# --- Frame 144 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: gesturing(1)
#   -> Saved relation: Frame=144, EventID=1, Type=gesturing, Actor=1
# --- FRAME 168 ---
# --- Frame 168 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(1)
#   -> Saved relation: Frame=168, EventID=1, Type=running, Actor=1
# --- FRAME 192 ---
# --- Frame 192 (gemini) ---
# Rate limiter: waiting 0.05 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 216 ---
# --- Frame 216 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 4
#   -> Tracked object 3
#   -> Tracked object 2
#   -> Tracked object 6
#   -> Tracked object 5
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 240 ---
# --- Frame 240 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 6
#   -> Tracked object 4
#   -> Tracked object 3
#   -> Tracked object 2
#   -> Tracked object 5
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# VLM analysis complete. 241 video frames processed.
# Starting post-processing (sampling rate: 24)...
# Loaded 6 vis-relation rows.
# Computing duration intervals with merge logic...
# Consolidated 3 unique relation intervals.
# Filtered to 3 intervals with valid duration; saving...
# Intervals saved successfully.
# Interval construction complete.
#   Scene 3: running VLM...
# Starting video analysis: /home/ghiffaryr/iseql/multimodal-surveillance-iseql/data/videos/eval/scene3.mp4
# Provider: gemini, Model: gemini-3.6-flash, Grid: 2x4
# Sampling rate: 1 frame every 24 video frames
# --- FRAME 0 ---
# --- Frame 0 (gemini) ---
# Rate limiter: waiting 0.04 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> New object 1 (person)
#   -> New object 2 (street light)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 24 ---
# --- Frame 24 (gemini) ---
# Rate limiter: waiting 0.03 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 48 ---
# --- Frame 48 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 72 ---
# --- Frame 72 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 96 ---
# --- Frame 96 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(1)
#   -> Saved relation: Frame=96, EventID=1, Type=running, Actor=1
# --- FRAME 120 ---
# --- Frame 120 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(1)
#   -> Saved relation: Frame=120, EventID=1, Type=running, Actor=1
# --- FRAME 144 ---
# --- Frame 144 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(1)
#   -> Saved relation: Frame=144, EventID=1, Type=running, Actor=1
# --- FRAME 168 ---
# --- Frame 168 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(1)
#   -> Saved relation: Frame=168, EventID=1, Type=running, Actor=1
# --- FRAME 192 ---
# --- Frame 192 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(1)
#   -> Saved relation: Frame=192, EventID=1, Type=running, Actor=1
# --- FRAME 216 ---
# --- Frame 216 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(1)
#   -> Saved relation: Frame=216, EventID=1, Type=running, Actor=1
# --- FRAME 240 ---
# --- Frame 240 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(1)
#   -> Saved relation: Frame=240, EventID=1, Type=running, Actor=1
# VLM analysis complete. 241 video frames processed.
# Starting post-processing (sampling rate: 24)...
# Loaded 7 vis-relation rows.
# Computing duration intervals with merge logic...
# Consolidated 1 unique relation intervals.
# Filtered to 1 intervals with valid duration; saving...
# Intervals saved successfully.
# Interval construction complete.
#   Scene 4: running VLM...
# Starting video analysis: /home/ghiffaryr/iseql/multimodal-surveillance-iseql/data/videos/eval/scene4.mp4
# Provider: gemini, Model: gemini-3.6-flash, Grid: 2x4
# Sampling rate: 1 frame every 24 video frames
# --- FRAME 0 ---
# --- Frame 0 (gemini) ---
# Rate limiter: waiting 0.05 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> New object 1 (person)
#   -> New object 2 (person)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: gesturing(2) physical_altercation(1, 2)
#   -> Saved relation: Frame=0, EventID=1, Type=gesturing, Actor=2
#   -> Saved relation: Frame=0, EventID=2, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=0, EventID=2, Type=physical_altercation, Actor=2
# --- FRAME 24 ---
# --- Frame 24 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: gesturing(2) physical_altercation(1, 2)
#   -> Saved relation: Frame=24, EventID=1, Type=gesturing, Actor=2
#   -> Saved relation: Frame=24, EventID=2, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=24, EventID=2, Type=physical_altercation, Actor=2
# --- FRAME 48 ---
# --- Frame 48 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(2) physical_altercation(1, 2)
#   -> Saved relation: Frame=48, EventID=1, Type=running, Actor=2
#   -> Saved relation: Frame=48, EventID=2, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=48, EventID=2, Type=physical_altercation, Actor=2
# --- FRAME 72 ---
# --- Frame 72 (gemini) ---
# Rate limiter: waiting 0.06 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(1, 2) running(2)
#   -> Saved relation: Frame=72, EventID=1, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=72, EventID=1, Type=physical_altercation, Actor=2
#   -> Saved relation: Frame=72, EventID=2, Type=running, Actor=2
# --- FRAME 96 ---
# --- Frame 96 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 2
#   -> Tracked object 1
#   -> New object 3 (person)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(1, 2)
#   -> Saved relation: Frame=96, EventID=1, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=96, EventID=1, Type=physical_altercation, Actor=2
# --- FRAME 120 ---
# --- Frame 120 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(2, 3)
#   -> Saved relation: Frame=120, EventID=1, Type=physical_altercation, Actor=3
#   -> Saved relation: Frame=120, EventID=1, Type=physical_altercation, Actor=2
# --- FRAME 144 ---
# --- Frame 144 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 1
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(1, 2) physical_altercation(1, 3) physical_altercation(2, 3)
#   -> Saved relation: Frame=144, EventID=1, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=144, EventID=1, Type=physical_altercation, Actor=2
#   -> Saved relation: Frame=144, EventID=2, Type=physical_altercation, Actor=3
#   -> Saved relation: Frame=144, EventID=2, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=144, EventID=3, Type=physical_altercation, Actor=3
#   -> Saved relation: Frame=144, EventID=3, Type=physical_altercation, Actor=2
# --- FRAME 168 ---
# --- Frame 168 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 1
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(1, 2) physical_altercation(2, 3)
#   -> Saved relation: Frame=168, EventID=1, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=168, EventID=1, Type=physical_altercation, Actor=2
#   -> Saved relation: Frame=168, EventID=2, Type=physical_altercation, Actor=3
#   -> Saved relation: Frame=168, EventID=2, Type=physical_altercation, Actor=2
# --- FRAME 192 ---
# --- Frame 192 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 1
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(2, 3) gesturing(3)
#   -> Saved relation: Frame=192, EventID=1, Type=physical_altercation, Actor=3
#   -> Saved relation: Frame=192, EventID=1, Type=physical_altercation, Actor=2
#   -> Saved relation: Frame=192, EventID=2, Type=gesturing, Actor=3
# --- FRAME 216 ---
# --- Frame 216 (gemini) ---
# Rate limiter: waiting 0.01 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 3
#   -> Tracked object 1
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: fearful_expression(3)
#   -> Saved relation: Frame=216, EventID=1, Type=fearful_expression, Actor=3
# --- FRAME 240 ---
# --- Frame 240 (gemini) ---
# Rate limiter: waiting 0.09 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 3
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# VLM analysis complete. 241 video frames processed.
# Starting post-processing (sampling rate: 24)...
# Loaded 26 vis-relation rows.
# Computing duration intervals with merge logic...
# Consolidated 8 unique relation intervals.
# Filtered to 8 intervals with valid duration; saving...
# Intervals saved successfully.
# Interval construction complete.
#   Scene 5: running VLM...
# Starting video analysis: /home/ghiffaryr/iseql/multimodal-surveillance-iseql/data/videos/eval/scene5.mp4
# Provider: gemini, Model: gemini-3.6-flash, Grid: 2x4
# Sampling rate: 1 frame every 24 video frames
# --- FRAME 0 ---
# --- Frame 0 (gemini) ---
# Rate limiter: waiting 0.03 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Expecting value: line 11 column 5 (char 228)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 24 ---
# --- Frame 24 (gemini) ---
# Rate limiter: waiting 0.06 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> New object 1 (person)
#   -> New object 2 (person)
#   -> New object 3 (car)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: gesturing(1) gesturing(2) physical_altercation(1, 2)
#   -> Saved relation: Frame=24, EventID=1, Type=gesturing, Actor=1
#   -> Saved relation: Frame=24, EventID=2, Type=gesturing, Actor=2
#   -> Saved relation: Frame=24, EventID=3, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=24, EventID=3, Type=physical_altercation, Actor=2
# --- FRAME 48 ---
# --- Frame 48 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(1, 2)
#   -> Saved relation: Frame=48, EventID=1, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=48, EventID=1, Type=physical_altercation, Actor=2
# --- FRAME 72 ---
# --- Frame 72 (gemini) ---
# Rate limiter: waiting 0.03 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Expecting value: line 3 column 109 (char 226)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(1, 2)
#   -> Saved relation: Frame=72, EventID=1, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=72, EventID=1, Type=physical_altercation, Actor=2
# --- FRAME 96 ---
# --- Frame 96 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> New object 4 (person)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(1, 2) running(4)
#   -> Saved relation: Frame=96, EventID=1, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=96, EventID=1, Type=physical_altercation, Actor=2
#   -> Saved relation: Frame=96, EventID=2, Type=running, Actor=4
# --- FRAME 120 ---
# --- Frame 120 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Unterminated string starting at: line 11 column 5 (char 233)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(1, 2, 4)
#   -> Saved relation: Frame=120, EventID=1, Type=physical_altercation, Actor=4
#   -> Saved relation: Frame=120, EventID=1, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=120, EventID=1, Type=physical_altercation, Actor=2
# --- FRAME 144 ---
# --- Frame 144 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Expecting property name enclosed in double quotes: line 10 column 63 (char 228)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(1, 2, 4)
#   -> Saved relation: Frame=144, EventID=1, Type=physical_altercation, Actor=4
#   -> Saved relation: Frame=144, EventID=1, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=144, EventID=1, Type=physical_altercation, Actor=2
# --- FRAME 168 ---
# --- Frame 168 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Expecting value: line 1 column 1 (char 0)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(2, 4)
#   -> Saved relation: Frame=168, EventID=1, Type=physical_altercation, Actor=4
#   -> Saved relation: Frame=168, EventID=1, Type=physical_altercation, Actor=2
# --- FRAME 192 ---
# --- Frame 192 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Unterminated string starting at: line 10 column 20 (char 191)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(1) running(4)
#   -> Saved relation: Frame=192, EventID=1, Type=running, Actor=1
#   -> Saved relation: Frame=192, EventID=2, Type=running, Actor=4
# --- FRAME 216 ---
# --- Frame 216 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 240 ---
# --- Frame 240 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 3
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# VLM analysis complete. 241 video frames processed.
# Starting post-processing (sampling rate: 24)...
# Loaded 21 vis-relation rows.
# Computing duration intervals with merge logic...
# Consolidated 8 unique relation intervals.
# Filtered to 8 intervals with valid duration; saving...
# Intervals saved successfully.
# Interval construction complete.
#   Scene 6: running VLM...
# Starting video analysis: /home/ghiffaryr/iseql/multimodal-surveillance-iseql/data/videos/eval/scene6.mp4
# Provider: gemini, Model: gemini-3.6-flash, Grid: 2x4
# Sampling rate: 1 frame every 24 video frames
# --- FRAME 0 ---
# --- Frame 0 (gemini) ---
# Rate limiter: waiting 0.04 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Unterminated string starting at: line 4 column 38 (char 224)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 24 ---
# --- Frame 24 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> New object 1 (dumpster)
#   -> New object 2 (object)
#   -> New object 3 (person)
#   -> New object 4 (person)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: gesturing(4)
#   -> Saved relation: Frame=24, EventID=1, Type=gesturing, Actor=4
# --- FRAME 48 ---
# --- Frame 48 (gemini) ---
# Rate limiter: waiting 0.04 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(3, 4)
#   -> Saved relation: Frame=48, EventID=1, Type=physical_altercation, Actor=3
#   -> Saved relation: Frame=48, EventID=1, Type=physical_altercation, Actor=4
# --- FRAME 72 ---
# --- Frame 72 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: gesturing(4)
#   -> Saved relation: Frame=72, EventID=1, Type=gesturing, Actor=4
# --- FRAME 96 ---
# --- Frame 96 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: gesturing(4)
#   -> Saved relation: Frame=96, EventID=1, Type=gesturing, Actor=4
# --- FRAME 120 ---
# --- Frame 120 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 144 ---
# --- Frame 144 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 168 ---
# --- Frame 168 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 192 ---
# --- Frame 192 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 216 ---
# --- Frame 216 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 240 ---
# --- Frame 240 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# VLM analysis complete. 241 video frames processed.
# Starting post-processing (sampling rate: 24)...
# Loaded 5 vis-relation rows.
# Computing duration intervals with merge logic...
# Consolidated 2 unique relation intervals.
# Filtered to 2 intervals with valid duration; saving...
# Intervals saved successfully.
# Interval construction complete.
#   Scene 7: running VLM...
# Starting video analysis: /home/ghiffaryr/iseql/multimodal-surveillance-iseql/data/videos/eval/scene7.mp4
# Provider: gemini, Model: gemini-3.6-flash, Grid: 2x4
# Sampling rate: 1 frame every 24 video frames
# --- FRAME 0 ---
# --- Frame 0 (gemini) ---
# Rate limiter: waiting 0.04 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Expecting value: line 4 column 75 (char 257)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 24 ---
# --- Frame 24 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> New object 1 (car)
#   -> New object 2 (car)
#   -> New object 3 (car)
#   -> New object 4 (car)
#   -> New object 5 (car)
#   -> New object 6 (person)
#   -> New object 7 (person)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: suspicious_near_vehicle(6, 2) gunshot_visible(6)
#   -> Saved relation: Frame=24, EventID=1, Type=suspicious_near_vehicle, Actor=6
#   -> Saved relation: Frame=24, EventID=1, Type=suspicious_near_vehicle, Actor=2
#   -> Saved relation: Frame=24, EventID=2, Type=gunshot_visible, Actor=6
# --- FRAME 48 ---
# --- Frame 48 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
#   -> Tracked object 7
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: gesturing(7) suspicious_near_vehicle(6, 2) physical_altercation(6, 7) gunshot_visible(6)
#   -> Saved relation: Frame=48, EventID=1, Type=gesturing, Actor=7
#   -> Saved relation: Frame=48, EventID=2, Type=suspicious_near_vehicle, Actor=6
#   -> Saved relation: Frame=48, EventID=2, Type=suspicious_near_vehicle, Actor=2
#   -> Saved relation: Frame=48, EventID=3, Type=physical_altercation, Actor=6
#   -> Saved relation: Frame=48, EventID=3, Type=physical_altercation, Actor=7
#   -> Saved relation: Frame=48, EventID=4, Type=gunshot_visible, Actor=6
# --- FRAME 72 ---
# --- Frame 72 (gemini) ---
# Rate limiter: waiting 0.04 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
#   -> Tracked object 7
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: gesturing(7) physical_altercation(6, 7) gunshot_visible(6)
#   -> Saved relation: Frame=72, EventID=1, Type=gesturing, Actor=7
#   -> Saved relation: Frame=72, EventID=2, Type=physical_altercation, Actor=6
#   -> Saved relation: Frame=72, EventID=2, Type=physical_altercation, Actor=7
#   -> Saved relation: Frame=72, EventID=3, Type=gunshot_visible, Actor=6
# --- FRAME 96 ---
# --- Frame 96 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
#   -> Tracked object 7
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(6, 7) gunshot_visible(6)
#   -> Saved relation: Frame=96, EventID=1, Type=physical_altercation, Actor=6
#   -> Saved relation: Frame=96, EventID=1, Type=physical_altercation, Actor=7
#   -> Saved relation: Frame=96, EventID=2, Type=gunshot_visible, Actor=6
# --- FRAME 120 ---
# --- Frame 120 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
#   -> Tracked object 7
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(7) suspicious_near_vehicle(6, 2) explosion_visible(2)
#   -> Saved relation: Frame=120, EventID=1, Type=running, Actor=7
#   -> Saved relation: Frame=120, EventID=2, Type=suspicious_near_vehicle, Actor=6
#   -> Saved relation: Frame=120, EventID=2, Type=suspicious_near_vehicle, Actor=2
#   -> Saved relation: Frame=120, EventID=3, Type=explosion_visible, Actor=2
# --- FRAME 144 ---
# --- Frame 144 (gemini) ---
# Rate limiter: waiting 0.03 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
#   -> Tracked object 7
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(6) running(7) explosion_visible(2)
#   -> Saved relation: Frame=144, EventID=1, Type=running, Actor=6
#   -> Saved relation: Frame=144, EventID=2, Type=running, Actor=7
#   -> Saved relation: Frame=144, EventID=3, Type=explosion_visible, Actor=2
# --- FRAME 168 ---
# --- Frame 168 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
#   -> Tracked object 7
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(6) running(7) explosion_visible(2)
#   -> Saved relation: Frame=168, EventID=1, Type=running, Actor=6
#   -> Saved relation: Frame=168, EventID=2, Type=running, Actor=7
#   -> Saved relation: Frame=168, EventID=3, Type=explosion_visible, Actor=2
# --- FRAME 192 ---
# --- Frame 192 (gemini) ---
# Rate limiter: waiting 0.03 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(6) running(7) explosion_visible(2)
#   -> Saved relation: Frame=192, EventID=1, Type=running, Actor=6
#   -> Saved relation: Frame=192, EventID=2, Type=running, Actor=7
#   -> Saved relation: Frame=192, EventID=3, Type=explosion_visible, Actor=2
# --- FRAME 216 ---
# --- Frame 216 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(6) running(7) explosion_visible(2)
#   -> Saved relation: Frame=216, EventID=1, Type=running, Actor=6
#   -> Saved relation: Frame=216, EventID=2, Type=running, Actor=7
#   -> Saved relation: Frame=216, EventID=3, Type=explosion_visible, Actor=2
# --- FRAME 240 ---
# --- Frame 240 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: explosion_visible(2) running(6) running(7)
#   -> Saved relation: Frame=240, EventID=1, Type=explosion_visible, Actor=2
#   -> Saved relation: Frame=240, EventID=2, Type=running, Actor=6
#   -> Saved relation: Frame=240, EventID=3, Type=running, Actor=7
# VLM analysis complete. 241 video frames processed.
# Starting post-processing (sampling rate: 24)...
# Loaded 35 vis-relation rows.
# Computing duration intervals with merge logic...
# Consolidated 8 unique relation intervals.
# Filtered to 8 intervals with valid duration; saving...
# Intervals saved successfully.
# Interval construction complete.
#   Scene 8: running VLM...
# Starting video analysis: /home/ghiffaryr/iseql/multimodal-surveillance-iseql/data/videos/eval/scene8.mp4
# Provider: gemini, Model: gemini-3.6-flash, Grid: 2x4
# Sampling rate: 1 frame every 24 video frames
# --- FRAME 0 ---
# --- Frame 0 (gemini) ---
# Rate limiter: waiting 0.03 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> New object 1 (car)
#   -> New object 2 (car)
#   -> New object 3 (person)
#   -> New object 4 (person)
#   -> New object 5 (car)
#   -> New object 6 (car)
#   -> New object 7 (person)
#   -> New object 8 (car)
#   -> New object 9 (car)
#   -> New object 10 (car)
#   -> New object 11 (car)
#   -> New object 12 (person)
#   -> New object 13 (car)
#   -> New object 14 (person)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 24 ---
# --- Frame 24 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Unterminated string starting at: line 4 column 13 (char 211)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 48 ---
# --- Frame 48 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Expecting value: line 4 column 9 (char 207)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: suspicious_near_vehicle(4, 5) suspicious_near_vehicle(12, 13)
#   -> Saved relation: Frame=48, EventID=1, Type=suspicious_near_vehicle, Actor=4
#   -> Saved relation: Frame=48, EventID=1, Type=suspicious_near_vehicle, Actor=5
#   -> Saved relation: Frame=48, EventID=2, Type=suspicious_near_vehicle, Actor=13
#   -> Saved relation: Frame=48, EventID=2, Type=suspicious_near_vehicle, Actor=12
# --- FRAME 72 ---
# --- Frame 72 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Unterminated string starting at: line 4 column 13 (char 211)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 96 ---
# --- Frame 96 (gemini) ---
# Rate limiter: waiting 0.06 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Unterminated string starting at: line 4 column 4 (char 220)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(3) running(14) suspicious_near_vehicle(12, 11)
#   -> Saved relation: Frame=96, EventID=1, Type=running, Actor=3
#   -> Saved relation: Frame=96, EventID=2, Type=running, Actor=14
#   -> Saved relation: Frame=96, EventID=3, Type=suspicious_near_vehicle, Actor=12
#   -> Saved relation: Frame=96, EventID=3, Type=suspicious_near_vehicle, Actor=11
# --- FRAME 120 ---
# --- Frame 120 (gemini) ---
# Rate limiter: waiting 0.06 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Expecting value: line 53 column 14 (char 1027)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(3)
#   -> Saved relation: Frame=120, EventID=1, Type=running, Actor=3
# --- FRAME 144 ---
# --- Frame 144 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Unterminated string starting at: line 4 column 13 (char 211)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 168 ---
# --- Frame 168 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Unterminated string starting at: line 10 column 48 (char 783)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 192 ---
# --- Frame 192 (gemini) ---
# Rate limiter: waiting 0.04 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 5
#   -> Tracked object 8
#   -> Tracked object 9
#   -> Tracked object 10
#   -> Tracked object 11
#   -> Tracked object 13
#   -> Tracked object 14
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(14)
#   -> Saved relation: Frame=192, EventID=1, Type=running, Actor=14
# --- FRAME 216 ---
# --- Frame 216 (gemini) ---
# Rate limiter: waiting 0.06 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Expecting property name enclosed in double quotes: line 41 column 22 (char 831)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 240 ---
# --- Frame 240 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 5
#   -> Tracked object 8
#   -> Tracked object 9
#   -> Tracked object 10
#   -> Tracked object 11
#   -> Tracked object 13
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# VLM analysis complete. 241 video frames processed.
# Starting post-processing (sampling rate: 24)...
# Loaded 10 vis-relation rows.
# Computing duration intervals with merge logic...
# Consolidated 6 unique relation intervals.
# Filtered to 6 intervals with valid duration; saving...
# Intervals saved successfully.
# Interval construction complete.
#   Scene 9: running VLM...
# Starting video analysis: /home/ghiffaryr/iseql/multimodal-surveillance-iseql/data/videos/eval/scene9.mp4
# Provider: gemini, Model: gemini-3.6-flash, Grid: 2x4
# Sampling rate: 1 frame every 24 video frames
# --- FRAME 0 ---
# --- Frame 0 (gemini) ---
# Rate limiter: waiting 0.05 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Expecting value: line 11 column 5 (char 210)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 24 ---
# --- Frame 24 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> New object 1 (person)
#   -> New object 2 (person)
#   -> New object 3 (car)
#   -> New object 4 (car)
#   -> New object 5 (car)
#   -> New object 6 (car)
#   -> New object 7 (car)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: suspicious_near_vehicle(2, 6)
#   -> Saved relation: Frame=24, EventID=1, Type=suspicious_near_vehicle, Actor=6
#   -> Saved relation: Frame=24, EventID=1, Type=suspicious_near_vehicle, Actor=2
# --- FRAME 48 ---
# --- Frame 48 (gemini) ---
# Rate limiter: waiting 0.04 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
#   -> Tracked object 7
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: suspicious_near_vehicle(1, 3) suspicious_near_vehicle(2, 6)
#   -> Saved relation: Frame=48, EventID=1, Type=suspicious_near_vehicle, Actor=3
#   -> Saved relation: Frame=48, EventID=1, Type=suspicious_near_vehicle, Actor=1
#   -> Saved relation: Frame=48, EventID=2, Type=suspicious_near_vehicle, Actor=6
#   -> Saved relation: Frame=48, EventID=2, Type=suspicious_near_vehicle, Actor=2
# --- FRAME 72 ---
# --- Frame 72 (gemini) ---
# Rate limiter: waiting 0.02 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Unterminated string starting at: line 4 column 4 (char 253)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: suspicious_near_vehicle(1, 3) suspicious_near_vehicle(2, 3)
#   -> Saved relation: Frame=72, EventID=1, Type=suspicious_near_vehicle, Actor=3
#   -> Saved relation: Frame=72, EventID=1, Type=suspicious_near_vehicle, Actor=1
#   -> Saved relation: Frame=72, EventID=2, Type=suspicious_near_vehicle, Actor=3
#   -> Saved relation: Frame=72, EventID=2, Type=suspicious_near_vehicle, Actor=2
# --- FRAME 96 ---
# --- Frame 96 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> New object 8 (person)
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
#   -> Tracked object 7
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: physical_altercation(1, 8) suspicious_near_vehicle(1, 3) suspicious_near_vehicle(8, 3) suspicious_near_vehicle(2, 6)
#   -> Saved relation: Frame=96, EventID=1, Type=physical_altercation, Actor=8
#   -> Saved relation: Frame=96, EventID=1, Type=physical_altercation, Actor=1
#   -> Saved relation: Frame=96, EventID=2, Type=suspicious_near_vehicle, Actor=3
#   -> Saved relation: Frame=96, EventID=2, Type=suspicious_near_vehicle, Actor=1
#   -> Saved relation: Frame=96, EventID=3, Type=suspicious_near_vehicle, Actor=8
#   -> Saved relation: Frame=96, EventID=3, Type=suspicious_near_vehicle, Actor=3
# ...
#   -> Saved relation: Frame=72, EventID=1, Type=carrying, Actor=1
#   -> Saved relation: Frame=72, EventID=1, Type=carrying, Actor=5
#   -> Saved relation: Frame=72, EventID=2, Type=fearful_expression, Actor=1
# --- FRAME 96 ---
# --- Frame 96 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(1, 5)
#   -> Saved relation: Frame=96, EventID=1, Type=carrying, Actor=1
#   -> Saved relation: Frame=96, EventID=1, Type=carrying, Actor=5
# --- FRAME 120 ---
# --- Frame 120 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 2
#   -> Tracked object 1
#   -> Tracked object 6
#   -> Tracked object 5
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(1, 5) carrying(6, 5)
#   -> Saved relation: Frame=120, EventID=1, Type=carrying, Actor=1
#   -> Saved relation: Frame=120, EventID=1, Type=carrying, Actor=5
#   -> Saved relation: Frame=120, EventID=2, Type=carrying, Actor=6
#   -> Saved relation: Frame=120, EventID=2, Type=carrying, Actor=5
# --- FRAME 144 ---
# --- Frame 144 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 2
#   -> Tracked object 1
#   -> Tracked object 6
#   -> Tracked object 5
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(6, 5)
#   -> Saved relation: Frame=144, EventID=1, Type=carrying, Actor=6
#   -> Saved relation: Frame=144, EventID=1, Type=carrying, Actor=5
# --- FRAME 168 ---
# --- Frame 168 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(6, 5) fearful_expression(1)
#   -> Saved relation: Frame=168, EventID=1, Type=carrying, Actor=6
#   -> Saved relation: Frame=168, EventID=1, Type=carrying, Actor=5
#   -> Saved relation: Frame=168, EventID=2, Type=fearful_expression, Actor=1
# --- FRAME 192 ---
# --- Frame 192 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 6
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: running(1) carrying(6, 5)
#   -> Saved relation: Frame=192, EventID=1, Type=running, Actor=1
#   -> Saved relation: Frame=192, EventID=2, Type=carrying, Actor=6
#   -> Saved relation: Frame=192, EventID=2, Type=carrying, Actor=5
# --- FRAME 216 ---
# --- Frame 216 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 240 ---
# --- Frame 240 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 3
#   -> Tracked object 2
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(6, 5)
#   -> Saved relation: Frame=240, EventID=1, Type=carrying, Actor=6
#   -> Saved relation: Frame=240, EventID=1, Type=carrying, Actor=5
# VLM analysis complete. 241 video frames processed.
# Starting post-processing (sampling rate: 24)...
# Loaded 23 vis-relation rows.
# Computing duration intervals with merge logic...
# Consolidated 6 unique relation intervals.
# Filtered to 6 intervals with valid duration; saving...
# Intervals saved successfully.
# Interval construction complete.
#   Scene 39: running VLM...
# Starting video analysis: /home/ghiffaryr/iseql/multimodal-surveillance-iseql/data/videos/eval/scene39.mp4
# Provider: gemini, Model: gemini-3.6-flash, Grid: 2x4
# Sampling rate: 1 frame every 24 video frames
# --- FRAME 0 ---
# --- Frame 0 (gemini) ---
# Rate limiter: waiting 0.03 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> New object 1 (person)
#   -> New object 2 (object)
#   -> New object 3 (car)
#   -> New object 4 (car)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(1, 2)
#   -> Saved relation: Frame=0, EventID=1, Type=carrying, Actor=1
#   -> Saved relation: Frame=0, EventID=1, Type=carrying, Actor=2
# --- FRAME 24 ---
# --- Frame 24 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(1, 2)
#   -> Saved relation: Frame=24, EventID=1, Type=carrying, Actor=1
#   -> Saved relation: Frame=24, EventID=1, Type=carrying, Actor=2
# --- FRAME 48 ---
# --- Frame 48 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(1, 2)
#   -> Saved relation: Frame=48, EventID=1, Type=carrying, Actor=1
#   -> Saved relation: Frame=48, EventID=1, Type=carrying, Actor=2
# --- FRAME 72 ---
# --- Frame 72 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(1, 2)
#   -> Saved relation: Frame=72, EventID=1, Type=carrying, Actor=1
#   -> Saved relation: Frame=72, EventID=1, Type=carrying, Actor=2
# --- FRAME 96 ---
# --- Frame 96 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(1, 2) gesturing(1)
#   -> Saved relation: Frame=96, EventID=1, Type=carrying, Actor=1
#   -> Saved relation: Frame=96, EventID=1, Type=carrying, Actor=2
#   -> Saved relation: Frame=96, EventID=2, Type=gesturing, Actor=1
# --- FRAME 120 ---
# --- Frame 120 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(1, 2)
#   -> Saved relation: Frame=120, EventID=1, Type=carrying, Actor=1
#   -> Saved relation: Frame=120, EventID=1, Type=carrying, Actor=2
# --- FRAME 144 ---
# --- Frame 144 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(1, 2)
#   -> Saved relation: Frame=144, EventID=1, Type=carrying, Actor=1
#   -> Saved relation: Frame=144, EventID=1, Type=carrying, Actor=2
# --- FRAME 168 ---
# --- Frame 168 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(1, 2)
#   -> Saved relation: Frame=168, EventID=1, Type=carrying, Actor=1
#   -> Saved relation: Frame=168, EventID=1, Type=carrying, Actor=2
# --- FRAME 192 ---
# --- Frame 192 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(1, 2)
#   -> Saved relation: Frame=192, EventID=1, Type=carrying, Actor=1
#   -> Saved relation: Frame=192, EventID=1, Type=carrying, Actor=2
# --- FRAME 216 ---
# --- Frame 216 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 240 ---
# --- Frame 240 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# VLM analysis complete. 241 video frames processed.
# Starting post-processing (sampling rate: 24)...
# Loaded 19 vis-relation rows.
# Computing duration intervals with merge logic...
# Consolidated 2 unique relation intervals.
# Filtered to 2 intervals with valid duration; saving...
# Intervals saved successfully.
# Interval construction complete.
#   Scene 40: running VLM...
# Starting video analysis: /home/ghiffaryr/iseql/multimodal-surveillance-iseql/data/videos/eval/scene40.mp4
# Provider: gemini, Model: gemini-3.6-flash, Grid: 2x4
# Sampling rate: 1 frame every 24 video frames
# --- FRAME 0 ---
# --- Frame 0 (gemini) ---
# Rate limiter: waiting 0.04 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> New object 1 (street lamp)
#   -> New object 2 (car)
#   -> New object 3 (car)
#   -> New object 4 (fire hydrant)
#   -> New object 5 (person)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# --- FRAME 24 ---
# --- Frame 24 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 5
#   -> New object 6 (object)
#   -> Tracked object 4
#   -> Tracked object 3
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(5, 6)
#   -> Saved relation: Frame=24, EventID=1, Type=carrying, Actor=6
#   -> Saved relation: Frame=24, EventID=1, Type=carrying, Actor=5
# --- FRAME 48 ---
# --- Frame 48 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(5, 6)
#   -> Saved relation: Frame=48, EventID=1, Type=carrying, Actor=6
#   -> Saved relation: Frame=48, EventID=1, Type=carrying, Actor=5
# --- FRAME 72 ---
# --- Frame 72 (gemini) ---
# Rate limiter: waiting 0.07 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 5
#   -> Tracked object 6
#   -> Tracked object 4
#   -> Tracked object 3
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(5, 6)
#   -> Saved relation: Frame=72, EventID=1, Type=carrying, Actor=6
#   -> Saved relation: Frame=72, EventID=1, Type=carrying, Actor=5
# --- FRAME 96 ---
# --- Frame 96 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(5, 6) gesturing(5)
#   -> Saved relation: Frame=96, EventID=1, Type=carrying, Actor=6
#   -> Saved relation: Frame=96, EventID=1, Type=carrying, Actor=5
#   -> Saved relation: Frame=96, EventID=2, Type=gesturing, Actor=5
# --- FRAME 120 ---
# --- Frame 120 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 5
#   -> Tracked object 6
#   -> Tracked object 4
#   -> Tracked object 3
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(5, 6) gesturing(5)
#   -> Saved relation: Frame=120, EventID=1, Type=carrying, Actor=6
#   -> Saved relation: Frame=120, EventID=1, Type=carrying, Actor=5
#   -> Saved relation: Frame=120, EventID=2, Type=gesturing, Actor=5
# --- FRAME 144 ---
# --- Frame 144 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 5
#   -> Tracked object 6
#   -> Tracked object 4
#   -> Tracked object 3
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(5, 6)
#   -> Saved relation: Frame=144, EventID=1, Type=carrying, Actor=6
#   -> Saved relation: Frame=144, EventID=1, Type=carrying, Actor=5
# --- FRAME 168 ---
# --- Frame 168 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
# Failed to parse object JSON: Unterminated string starting at: line 3 column 47 (char 176)
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(5, 6)
#   -> Saved relation: Frame=168, EventID=1, Type=carrying, Actor=6
#   -> Saved relation: Frame=168, EventID=1, Type=carrying, Actor=5
# --- FRAME 192 ---
# --- Frame 192 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 5
#   -> Tracked object 6
#   -> Tracked object 4
#   -> Tracked object 3
#   -> Tracked object 2
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(5, 6)
#   -> Saved relation: Frame=192, EventID=1, Type=carrying, Actor=6
#   -> Saved relation: Frame=192, EventID=1, Type=carrying, Actor=5
# --- FRAME 216 ---
# --- Frame 216 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
#   -> Tracked object 5
#   -> Tracked object 6
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: carrying(5, 6)
#   -> Saved relation: Frame=216, EventID=1, Type=carrying, Actor=6
#   -> Saved relation: Frame=216, EventID=1, Type=carrying, Actor=5
# --- FRAME 240 ---
# --- Frame 240 (gemini) ---
# Rate limiter: waiting 0.08 s before next VLM call
# Calling gemini API (attempt 1/10)
#   -> Tracked object 1
#   -> Tracked object 2
#   -> Tracked object 3
#   -> Tracked object 4
# Analyzing relations...
# Rate limiter: waiting 0.10 s before next VLM call
# Calling gemini API (attempt 1/10)
# Relations: none()
# VLM analysis complete. 241 video frames processed.
# Starting post-processing (sampling rate: 24)...
# Loaded 20 vis-relation rows.
# Computing duration intervals with merge logic...
# Consolidated 2 unique relation intervals.
# Filtered to 2 intervals with valid duration; saving...
# Intervals saved successfully.
# Interval construction complete.
# VLM + interval building done.

# %%
# ── Event-level evaluation ──
event_rows = []
conn = sqlite3.connect(str(db_path))

for _, row in expected_df.iterrows():
    aid = f'gemini_3_6_flash_s{row["scene"]}'
    evt = row['event']
    sql_map = queries_for_condition("A", DELTAS, analysis_id=aid)
    sql = sql_map.get(evt, 'SELECT 0 WHERE 1=0')
    df = pd.read_sql_query(sql, conn)
    det = not df.empty
    result = 'TP' if det else 'FN'

    vis_rels = ''
    if det:
        parts = []
        for _, r in df.iterrows():
            rel = evt
            sf = int(r['StartFrame'])
            ef = int(r['EndFrame'])
            parts.append(f'{rel}({sf}-{ef})')
        vis_rels = ', '.join(parts)
    else:
        all_rels = conn.execute(
            'SELECT RelationType, StartFrame, EndFrame FROM VisualPerInterval WHERE AnalysisID = ?',
            (aid,)
        ).fetchall()
        if all_rels:
            parts = [f'{r}({sf}-{ef})' for r, sf, ef in all_rels]
            vis_rels = ', '.join(parts)

    event_rows.append({
        'scene': row['scene'], 'event': evt,
        'detected': 'YES' if det else 'NO', 'result': result,
        'relations': vis_rels,
    })
# FP pass: check negative scenes
all_scenes = sorted(expected_df['scene'].unique())
for evt_fp in sorted(event_metrics_events := sorted(expected_df['event'].unique())):
    pos_scenes = set(expected_df[expected_df['event'] == evt_fp]['scene'])
    for neg_scene in all_scenes:
        if neg_scene in pos_scenes:
            continue
        aid = f'gemini_3_6_flash_s{neg_scene}'
        sql_map = queries_for_condition("A", DELTAS, analysis_id=aid)
        sql = sql_map.get(evt_fp, 'SELECT 0 WHERE 1=0')
        try:
            df = pd.read_sql_query(sql, conn)
            if not df.empty:
                rel_str = evt_fp + '(' + str(int(df.iloc[0].get('StartFrame', 0))) + '-' + str(int(df.iloc[0].get('EndFrame', 0))) + ')'
                event_rows.append({'scene': neg_scene, 'event': evt_fp,
                    'detected': 'YES', 'result': 'FP',
                    'relations': rel_str})
        except:
            pass

conn.close()
edf = pd.DataFrame(event_rows)
edf['relations'] = edf['relations'].fillna('')

# Summary metrics
metrics = []
for evt in sorted(edf['event'].unique()):
    sub = edf[edf['event'] == evt]
    tpp = len(sub[sub['result'] == 'TP'])
    fpp = len(sub[sub['result'] == 'FP'])
    fnn = len(sub[sub['result'] == 'FN'])
    support = tpp + fnn
    p = tpp / (tpp + fpp) if (tpp + fpp) > 0 else 0.0
    r = tpp / (tpp + fnn) if (tpp + fnn) > 0 else 0.0
    f1 = 2*p*r/(p+r) if (p+r) > 0 else 0.0
    metrics.append({
        'event': evt, 'precision': round(p, 3), 'recall': round(r, 3), 'f1': round(f1, 3), 'TP': tpp, 'FP': fpp, 'FN': fnn, 'support': support
    })
metrics_df = pd.DataFrame(metrics)
print('\n=== Event Summary ===')
print(metrics_df.to_string(index=False))

# Write xlsx
with pd.ExcelWriter(ANALYSIS_DIR / f'visual_event_eval_gemini_3_6_flash.xlsx') as writer:
    metrics_df.to_excel(writer, sheet_name='Summary', index=False)
    for sc in sorted(expected_df['scene'].unique()):
        sc_df = edf[edf['scene'] == sc]
        if not sc_df.empty:
            sc_df.to_excel(writer, sheet_name=f'Scene_{sc}', index=False)
# Out:
# === Event Summary ===
#                event  precision  recall    f1  TP  FP  FN  support
#             distress      0.333     0.4 0.364   2   4   3        5
#                fight      0.714     1.0 0.833   5   2   0        5
#      gesture_overlap      1.000     0.6 0.750   3   0   2        5
# gunshot_or_explosion      1.000     0.4 0.571   2   0   3        5
#              handoff      0.000     0.0 0.000   0   0   5        5
#            loitering      0.800     0.8 0.800   4   1   1        5
#    vehicle_collision      1.000     1.0 1.000   5   0   0        5
#       vehicle_escape      0.500     0.6 0.545   3   3   2        5

# %%
# ── Ablation summary ──
tp = len(edf[edf['result'] == 'TP'])
fp = len(edf[edf['result'] == 'FP'])
fn = len(edf[edf['result'] == 'FN'])
support = tp + fn
precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0

conn2 = sqlite3.connect(str(db_path))
vpi = conn2.execute('SELECT COUNT(*) FROM VisualPerInterval').fetchone()[0]
conn2.close()

result_df = pd.DataFrame([{
    'visual': 'gemini_3_6_flash', 'reid': True,
    'precision': round(precision, 3), 'recall': round(recall, 3), 'f1': round(f1, 3),
    'TP': tp, 'FP': fp, 'FN': fn, 'support': support,
    'VPI': vpi,
}])
result_df.to_excel(ANALYSIS_DIR / 'summary.xlsx', index=False)
print(f'Summary: P={precision:.3f} R={recall:.3f} F1={f1:.3f} TP={tp} FP={fp} FN={fn} VPI={vpi}')
# Out:
# Summary: P=0.706 R=0.600 F1=0.649 TP=24 FP=10 FN=16 VPI=155

# %%
# ── Relation-level evaluation ──
relation_types = {
    'physical_altercation',
    'running', 'enter_or_exit_vehicle', 'carrying', 
    'suspicious_near_vehicle', 'vehicle_collision', 'gunshot_visible',
    'explosion_visible',
}

conn = sqlite3.connect(str(db_path))

rel_rows = []
for scene in sorted(expected_df['scene'].unique()):
    aid = f'gemini_3_6_flash_s{scene}'
    scene_gts = gt_visual[gt_visual['scene'] == scene]
    if scene_gts.empty:
        continue

    # VLM relations from VisualRelation table
    cur = conn.execute(
        'SELECT DISTINCT RelationType FROM VisualRelation WHERE AnalysisID = ?',
        (aid,)
    )
    vlm_rels = {row[0] for row in cur.fetchall()}

    gt_rels = set(scene_gts['class'].unique())

    for rel in sorted(relation_types):
        in_gt = rel in gt_rels
        in_vlm = rel in vlm_rels
        if in_gt and in_vlm:
            result = 'TP'
        elif in_gt and not in_vlm:
            result = 'FN'
        elif not in_gt and in_vlm:
            result = 'FP'
        else:
            result = 'TN'
        rel_rows.append({
            'scene': scene, 'relation': rel,
            'in_gt': 'YES' if in_gt else 'NO',
            'in_vlm': 'YES' if in_vlm else 'NO',
            'result': result,
        })

conn.close()
rdf = pd.DataFrame(rel_rows)

# Summary per relation type
rel_metrics = []
for rel in sorted(rdf['relation'].unique()):
    sub = rdf[rdf['relation'] == rel]
    tp = len(sub[sub['result'] == 'TP'])
    fn = len(sub[sub['result'] == 'FN'])
    fp = len(sub[sub['result'] == 'FP'])
    support = tp + fn
    p = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    r = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1 = 2*p*r/(p+r) if (p+r) > 0 else 0.0
    rel_metrics.append({
        'relation': rel, 'precision': round(p, 3), 'recall': round(r, 3), 'f1': round(f1, 3), 'TP': tp, 'FP': fp, 'FN': fn, 'support': support
    })

rm_df = pd.DataFrame(rel_metrics)
print('\n=== Relation Summary ===')
print(rm_df.to_string(index=False))

with pd.ExcelWriter(ANALYSIS_DIR / f'visual_relation_eval_gemini_3_6_flash.xlsx') as writer:
    rm_df.to_excel(writer, sheet_name='Summary', index=False)
    for sc in sorted(expected_df['scene'].unique()):
        sc_df = rdf[(rdf['scene'] == sc) & (rdf['result'] != 'TN')]
        if not sc_df.empty:
            sc_df.to_excel(writer, sheet_name=f'Scene_{sc}', index=False)

print(f'\nDone. XLSX written to {ANALYSIS_DIR}/')
# Out:
# === Relation Summary ===
#                relation  precision  recall    f1  TP  FP  FN  support
#                carrying      0.900   0.900 0.900   9   1   1       10
#         distressed_face      0.000   0.000 0.000   0   1   0        0
#   enter_or_exit_vehicle      0.417   1.000 0.588   5   7   0        5
#       explosion_visible      1.000   1.000 1.000   3   0   0        3
#      fearful_expression      0.333   0.400 0.364   2   4   3        5
#               gesturing      0.286   0.800 0.421   4  10   1        5
#         gunshot_visible      1.000   0.667 0.800   2   0   1        3
#    physical_altercation      0.714   1.000 0.833   5   2   0        5
#                 running      0.320   0.800 0.457   8  17   2       10
# suspicious_near_vehicle      0.250   1.000 0.400   5  15   0        5
#       vehicle_collision      1.000   1.000 1.000   5   0   0        5
#
# Done. XLSX written to /home/ghiffaryr/iseql/multimodal-surveillance-iseql/data/analysis_gemini_3_6_flash/
